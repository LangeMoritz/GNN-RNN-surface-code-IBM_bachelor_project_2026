# %%
#Test code for the MWPMDecoder class. Adjust parameters as needed for different jobs or code distances.
from mwpm_decoder import MWPMDecoder
from surface_code_miami import CHIP_MAP

distance = 3 # 5 if distance 5
t = 10  # Number of syndrome rounds (adjust if different)
job_path = 'ibm_jobs/job_d7553d5bjrds73ebv3s0_d3_T10_shots500.json'  # Path to your job file
simulator = False  # False for hardware jobs
shots = 500  # Number of shots (adjust if different)

layout = CHIP_MAP[distance]  # For the specified distance
decoder = MWPMDecoder(
    distance, t, job_path, simulator, shots,
    layout['ancilla'], layout['data'], layout['x_type'], 
    code_type="surface"
)
results = decoder.decode()
# d is the distance of the code
# i=0 is expected if surface codes are being used.
# pdet is the mean detection probability for the code.
# P_L is the logical error rate, with binomial standard error.
# Out:
# d=3, i=0, pdet=0.2030, P_L=0.482000 ± 0.022346

# %%
#Test code for the MWPMDecoder class. Adjust parameters as needed for different jobs or code distances.
from mwpm_decoder import MWPMDecoder
from surface_code_miami import CHIP_MAP

distance = 5 # 5 if distance 5
t = 50  # Number of syndrome rounds (adjust if different)
job_path = 'ibm_jobs/job_d75o6eu8faus73f0bgqg_d5_T50_shots500.json'  # Path to your job file
simulator = False  # False for hardware jobs
shots = 500  # Number of shots (adjust if different)

layout = CHIP_MAP[distance]  # For the specified distance
decoder = MWPMDecoder(
    distance, t, job_path, simulator, shots,
    layout['ancilla'], layout['data'], layout['x_type'], 
    code_type="surface" 
)
results = decoder.decode()
# d is the distance of the code
# i=0 is expected if surface codes are being used.
# pdet is the mean detection probability for the code.
# P_L is the logical error rate, with binomial standard error.
# Out:
# d=5, i=0, pdet=0.3711, P_L=0.522000 ± 0.022339
